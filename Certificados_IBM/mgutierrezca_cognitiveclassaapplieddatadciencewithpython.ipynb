# %% [markdown]
# ## Certificados Python Data Science IBM

# %% [markdown]
# # Nombre : Mateo Gutierrez Melo

# %% [markdown]
# ### Python for data science
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Data visualization with Python
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Data Analysis with Python
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Certificados en mi linkedin
#
# ##### URL perfil linkedin
# url : https://www.linkedin.com/in/mateogutierrezmelo/
#
#
#
# ![image.png](attachment:image.png)
